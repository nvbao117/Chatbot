# %%
# Out:
# The kernel failed to start as ' C extension module was built for another version of psutil (5.9.0 instead of 7.1.2); you may try to ' could not be imported from '5.9.0 instead of 7.1.2'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
